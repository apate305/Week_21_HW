# %% [markdown]
# https://week21resource.azurewebsites.net/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://week21resource.azurewebsites.net/all

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://week21resource.azurewebsites.net/year/2020

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://week21resource.azurewebsites.net/add

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
